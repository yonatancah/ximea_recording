# %%
import pandas as pd

# %%
pathto=r'D:\S3_replication\S3_rep_test\9989\S001\camera\XIMEARecording_T010_035_rat_visible_close_threaten_noweapons_safehouse.mkv\CAM1_XIMEARecording_T010_035_rat_visible_close_threaten_noweapons_safehouse.txt'

data=pd.read_csv(pathto)

# %%
data.diff().dropna().plot()
# Out:
# <AxesSubplot: >
