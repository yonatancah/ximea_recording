# %%
import pandas as pd

# %%
pathto=r'testtimestamp.txt'
# pathto=r'D:\S3_replication\S3_rep_test\9989\S001\camera\XIMEARecording_T013_026_snake_novisible_medium_null_noweapons_safehouse.mkv\CAM2_XIMEARecording_T013_026_snake_novisible_medium_null_noweapons_safehouse.txt'
data=pd.read_csv(pathto)

# %%
df=data.diff().dropna()['timestamp']

# %%
(1/(df/1e6)).round(1).plot()
# Out:
# <AxesSubplot: >

# %%
(1/(df/1e6)).round(1).hist()
# Out:
# <AxesSubplot: >

# %%
1/50
# Out:
# 0.02
