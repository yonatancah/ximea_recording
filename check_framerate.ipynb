# %%
import pandas as pd

# %%
# pathto=r'testtimestamp60fps.txt'
# pathto=r'D:\S3_replication\Rep_test_26_10_2023\15\S001\camera\XIMEARecording_T003_031_human_visible_medium_null_noweapons_safehouse.mkv\CAM4_XIMEARecording_T003_031_human_visible_medium_null_noweapons_safehouse.txt'
pathto=r'D:\Calibration_Uzay\CAM2_Calibration_Uzay.txt'
data=pd.read_csv(pathto)

# %%
df=data.diff().dropna()['timestamp']
df=1/(df/1e6) ## convert ms to fps
df.round(1).hist()
# Out:
# <AxesSubplot: >

# %%
df.round(1).plot()
# Out:
# <AxesSubplot: >

# %%
percentages = (df.value_counts() / len(df)) * 100  # Calculate percentages
percentages
# Out:
# 30.0003    74.667816
# 30.0012    25.332184
# Name: timestamp, dtype: float64
